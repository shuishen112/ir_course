# %%
# !pip install --upgrade git+https://github.com/Georgetown-IR-Lab/OpenNIR
# !pip install --upgrade git+https://github.com/terrierteam/pyterrier_t5
# Out:
# WARNING: Ignoring invalid distribution -orch (/maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -orch (/maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages)
# Collecting git+https://github.com/Georgetown-IR-Lab/OpenNIR
#   Cloning https://github.com/Georgetown-IR-Lab/OpenNIR to /tmp/pip-req-build-_ts7g2pw
#   Running command git clone --filter=blob:none --quiet https://github.com/Georgetown-IR-Lab/OpenNIR /tmp/pip-req-build-_ts7g2pw
#   Resolved https://github.com/Georgetown-IR-Lab/OpenNIR to commit 88a4679372f471a04d284a99404ffce2b7a1dc49
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.3.1 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from OpenNIR==0.1.0) (1.11.0)
# Collecting pytorch-pretrained-bert==0.6.1
#   Downloading pytorch_pretrained_bert-0.6.1-py3-none-any.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.3/114.3 KB 3.2 MB/s eta 0:00:00
# Collecting pytorch-transformers==1.1.0
#   Downloading pytorch_transformers-1.1.0-py3-none-any.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.1/158.1 KB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: tokenizers>=0.1.1 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from OpenNIR==0.1.0) (0.11.6)
# Requirement already satisfied: transformers>=4.3.3 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from OpenNIR==0.1.0) (4.16.2)
# Requirement already satisfied: tqdm>=4.38.0 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from OpenNIR==0.1.0) (4.63.0)
# Collecting colorlog==4.0.2
#   Downloading colorlog-4.0.2-py2.py3-none-any.whl (17 kB)
# Collecting terminaltables>=3.1.0
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: matplotlib>=3.0.2 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from OpenNIR==0.1.0) (3.5.1)
# Collecting seaborn>=0.9.0
#   Using cached seaborn-0.11.2-py3-none-any.whl (292 kB)
# Collecting python-ternary>=1.0.6
#   Downloading python_ternary-1.0.8-py3-none-any.whl (18 kB)
# Requirement already satisfied: beautifulsoup4>=4.9.3 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from OpenNIR==0.1.0) (4.10.0)
# Collecting html5lib>=1.0.1
#   Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 KB 6.0 MB/s eta 0:00:00
# Collecting Unidecode>=1.0.22
#   Downloading Unidecode-1.3.4-py3-none-any.whl (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.9/235.9 KB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: nltk>=3.4.5 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from OpenNIR==0.1.0) (3.6.7)
# Collecting sqlitedict>=1.6.0
#   Downloading sqlitedict-2.0.0.tar.gz (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.3/46.3 KB 2.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pytrec-eval-terrier>=0.5.1 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from OpenNIR==0.1.0) (0.5.1)
# Requirement already satisfied: gensim>=3.7.3 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from OpenNIR==0.1.0) (4.1.2)
# Requirement already satisfied: Cython>=0.29.2 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from OpenNIR==0.1.0) (0.29.27)
# Requirement already satisfied: pyjnius>=1.2.1 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from OpenNIR==0.1.0) (1.3.0)
# Requirement already satisfied: ir_datasets>=0.2.0 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from OpenNIR==0.1.0) (0.5.1)
# Requirement already satisfied: ir_measures>=0.2.1 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from OpenNIR==0.1.0) (0.2.3)
# Collecting pytools>=2018.5.2
#   Downloading pytools-2022.1.7.tar.gz (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.2/69.2 KB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting cached-property>=1.5.1
#   Downloading cached_property-1.5.2-py2.py3-none-any.whl (7.6 kB)
# Requirement already satisfied: boto3 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from pytorch-pretrained-bert==0.6.1->OpenNIR==0.1.0) (1.21.22)
# Requirement already satisfied: requests in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from pytorch-pretrained-bert==0.6.1->OpenNIR==0.1.0) (2.27.1)
# Requirement already satisfied: numpy in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from pytorch-pretrained-bert==0.6.1->OpenNIR==0.1.0) (1.22.1)
# Requirement already satisfied: regex in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from pytorch-pretrained-bert==0.6.1->OpenNIR==0.1.0) (2022.1.18)
# Requirement already satisfied: sentencepiece in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from pytorch-transformers==1.1.0->OpenNIR==0.1.0) (0.1.96)
# Requirement already satisfied: soupsieve>1.2 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from beautifulsoup4>=4.9.3->OpenNIR==0.1.0) (2.3.1)
# Requirement already satisfied: smart-open>=1.8.1 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from gensim>=3.7.3->OpenNIR==0.1.0) (5.2.1)
# Requirement already satisfied: scipy>=0.18.1 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from gensim>=3.7.3->OpenNIR==0.1.0) (1.7.3)
# Requirement already satisfied: six>=1.9 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from html5lib>=1.0.1->OpenNIR==0.1.0) (1.16.0)
# Requirement already satisfied: webencodings in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from html5lib>=1.0.1->OpenNIR==0.1.0) (0.5.1)
# Requirement already satisfied: zlib-state>=0.1.3 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from ir_datasets>=0.2.0->OpenNIR==0.1.0) (0.1.5)
# Requirement already satisfied: trec-car-tools>=2.5.4 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from ir_datasets>=0.2.0->OpenNIR==0.1.0) (2.6)
# Requirement already satisfied: lz4>=3.1.1 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from ir_datasets>=0.2.0->OpenNIR==0.1.0) (3.1.10)
# Requirement already satisfied: unlzw3>=0.2.1 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from ir_datasets>=0.2.0->OpenNIR==0.1.0) (0.2.1)
# Requirement already satisfied: warc3-wet>=0.2.3 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from ir_datasets>=0.2.0->OpenNIR==0.1.0) (0.2.3)
# Requirement already satisfied: ijson>=3.1.3 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from ir_datasets>=0.2.0->OpenNIR==0.1.0) (3.1.4)
# Requirement already satisfied: lxml>=4.5.2 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from ir_datasets>=0.2.0->OpenNIR==0.1.0) (4.7.1)
# Requirement already satisfied: warc3-wet-clueweb09>=0.2.5 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from ir_datasets>=0.2.0->OpenNIR==0.1.0) (0.2.5)
# Requirement already satisfied: pyyaml>=5.3.1 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from ir_datasets>=0.2.0->OpenNIR==0.1.0) (6.0)
# Requirement already satisfied: pyautocorpus>=0.1.1 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from ir_datasets>=0.2.0->OpenNIR==0.1.0) (0.1.8)
# Requirement already satisfied: pyndeval>=0.0.2 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from ir_measures>=0.2.1->OpenNIR==0.1.0) (0.0.2)
# Requirement already satisfied: cwl-eval>=1.0.10 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from ir_measures>=0.2.1->OpenNIR==0.1.0) (1.0.10)
# Requirement already satisfied: cycler>=0.10 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from matplotlib>=3.0.2->OpenNIR==0.1.0) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from matplotlib>=3.0.2->OpenNIR==0.1.0) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from matplotlib>=3.0.2->OpenNIR==0.1.0) (4.29.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from matplotlib>=3.0.2->OpenNIR==0.1.0) (3.0.7)
# Requirement already satisfied: packaging>=20.0 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from matplotlib>=3.0.2->OpenNIR==0.1.0) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from matplotlib>=3.0.2->OpenNIR==0.1.0) (9.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from matplotlib>=3.0.2->OpenNIR==0.1.0) (1.3.2)
# Requirement already satisfied: joblib in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from nltk>=3.4.5->OpenNIR==0.1.0) (1.1.0)
# Requirement already satisfied: click in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from nltk>=3.4.5->OpenNIR==0.1.0) (8.0.4)
# Requirement already satisfied: platformdirs>=2.2.0 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from pytools>=2018.5.2->OpenNIR==0.1.0) (2.5.1)
# Requirement already satisfied: typing_extensions>=4.0 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from pytools>=2018.5.2->OpenNIR==0.1.0) (4.1.1)
# Requirement already satisfied: pandas>=0.23 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from seaborn>=0.9.0->OpenNIR==0.1.0) (1.4.0)
# Requirement already satisfied: sacremoses in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from transformers>=4.3.3->OpenNIR==0.1.0) (0.0.47)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from transformers>=4.3.3->OpenNIR==0.1.0) (0.4.0)
# Requirement already satisfied: filelock in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from transformers>=4.3.3->OpenNIR==0.1.0) (3.4.2)
# Requirement already satisfied: pytz>=2020.1 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from pandas>=0.23->seaborn>=0.9.0->OpenNIR==0.1.0) (2021.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from requests->pytorch-pretrained-bert==0.6.1->OpenNIR==0.1.0) (2.0.11)
# Requirement already satisfied: idna<4,>=2.5 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from requests->pytorch-pretrained-bert==0.6.1->OpenNIR==0.1.0) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from requests->pytorch-pretrained-bert==0.6.1->OpenNIR==0.1.0) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from requests->pytorch-pretrained-bert==0.6.1->OpenNIR==0.1.0) (2021.10.8)
# Requirement already satisfied: cbor>=1.0.0 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from trec-car-tools>=2.5.4->ir_datasets>=0.2.0->OpenNIR==0.1.0) (1.0.0)
# Requirement already satisfied: botocore<1.25.0,>=1.24.22 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from boto3->pytorch-pretrained-bert==0.6.1->OpenNIR==0.1.0) (1.24.22)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from boto3->pytorch-pretrained-bert==0.6.1->OpenNIR==0.1.0) (1.0.0)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from boto3->pytorch-pretrained-bert==0.6.1->OpenNIR==0.1.0) (0.5.2)
# Building wheels for collected packages: OpenNIR, pytools, sqlitedict
#   Building wheel for OpenNIR (setup.py) ... done
#   Created wheel for OpenNIR: filename=OpenNIR-0.1.0-py3-none-any.whl size=55851484 sha256=6fb1dd241506093524111da72ab1dc677e7174033bf67cf9c202d4c9bf2617c2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-o7aee1io/wheels/d1/f8/fa/f842dc002e8a009eef13f7b049ed65b1bb40e3aa68b0ec5f16
#   Building wheel for pytools (setup.py) ... done
#   Created wheel for pytools: filename=pytools-2022.1.7-py2.py3-none-any.whl size=64772 sha256=53d174340a2d6c114dce829e4a45a7b05ee71f6c0fde0b2d30c2ca0a13d20360
#   Stored in directory: /maps/projects/futhark1/data/wzm289/.cache/pip/wheels/08/8c/fa/4a12fae1a8e923881f6175705667720583c2a1fe152a3a374f
#   Building wheel for sqlitedict (setup.py) ... done
#   Created wheel for sqlitedict: filename=sqlitedict-2.0.0-py3-none-any.whl size=15733 sha256=7759e7fdbee4ffe025d6782e7fd41e78ff6844018578e346059cf350b0922777
#   Stored in directory: /maps/projects/futhark1/data/wzm289/.cache/pip/wheels/48/a5/80/fa89dc26af0f4c280b500f5529978552379c1ce8907e0a281c
# Successfully built OpenNIR pytools sqlitedict
# WARNING: Ignoring invalid distribution -orch (/maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages)
# Installing collected packages: sqlitedict, colorlog, cached-property, Unidecode, terminaltables, pytools, html5lib, seaborn, python-ternary, pytorch-transformers, pytorch-pretrained-bert, OpenNIR
# WARNING: Ignoring invalid distribution -orch (/maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -orch (/maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -orch (/maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -orch (/maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -orch (/maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -orch (/maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -orch (/maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -orch (/maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -orch (/maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -orch (/maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -orch (/maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -orch (/maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages)
# Successfully installed OpenNIR-0.1.0 Unidecode-1.3.4 cached-property-1.5.2 colorlog-4.0.2 html5lib-1.1 python-ternary-1.0.8 pytools-2022.1.7 pytorch-pretrained-bert-0.6.1 pytorch-transformers-1.1.0 seaborn-0.11.2 sqlitedict-2.0.0 terminaltables-3.1.10
# WARNING: Ignoring invalid distribution -orch (/maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -orch (/maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -orch (/maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -orch (/maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages)
# Collecting git+https://github.com/terrierteam/pyterrier_t5
#   Cloning https://github.com/terrierteam/pyterrier_t5 to /tmp/pip-req-build-09qozv03
#   Running command git clone --filter=blob:none --quiet https://github.com/terrierteam/pyterrier_t5 /tmp/pip-req-build-09qozv03
#   Resolved https://github.com/terrierteam/pyterrier_t5 to commit 02eb202169b2672567e75a6f04720f7fc1dbc15b
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-terrier>=0.5.0 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from pyterrier-t5==0.0.1) (0.8.1)
# Requirement already satisfied: pandas in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from pyterrier-t5==0.0.1) (1.4.0)
# Requirement already satisfied: transformers>=4.0.0 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from pyterrier-t5==0.0.1) (4.16.2)
# Requirement already satisfied: torch in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from pyterrier-t5==0.0.1) (1.11.0)
# Requirement already satisfied: sentencepiece>=0.1.95 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from pyterrier-t5==0.0.1) (0.1.96)
# Requirement already satisfied: scipy in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.7.3)
# Requirement already satisfied: dill in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.3.4)
# Requirement already satisfied: jinja2 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (3.0.3)
# Requirement already satisfied: wget in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (3.2)
# Requirement already satisfied: chest in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.2.3)
# Requirement already satisfied: matchpy in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.5.5)
# Requirement already satisfied: requests in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (2.27.1)
# Requirement already satisfied: ir-measures>=0.2.0 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.2.3)
# Requirement already satisfied: tqdm in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (4.63.0)
# Requirement already satisfied: sklearn in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.0)
# Requirement already satisfied: deprecation in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (2.1.0)
# Requirement already satisfied: more-itertools in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (8.12.0)
# Requirement already satisfied: joblib in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.1.0)
# Requirement already satisfied: nptyping==1.4.4 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.4.4)
# Requirement already satisfied: numpy in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.22.1)
# Requirement already satisfied: ir-datasets>=0.3.2 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.5.1)
# Requirement already satisfied: pyjnius~=1.3.0 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.3.0)
# Requirement already satisfied: statsmodels in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.13.1)
# Requirement already satisfied: typish>=1.7.0 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from nptyping==1.4.4->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.9.3)
# Requirement already satisfied: packaging>=20.0 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from transformers>=4.0.0->pyterrier-t5==0.0.1) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from transformers>=4.0.0->pyterrier-t5==0.0.1) (6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from transformers>=4.0.0->pyterrier-t5==0.0.1) (0.4.0)
# Requirement already satisfied: tokenizers!=0.11.3,>=0.10.1 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from transformers>=4.0.0->pyterrier-t5==0.0.1) (0.11.6)
# Requirement already satisfied: filelock in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from transformers>=4.0.0->pyterrier-t5==0.0.1) (3.4.2)
# Requirement already satisfied: regex!=2019.12.17 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from transformers>=4.0.0->pyterrier-t5==0.0.1) (2022.1.18)
# Requirement already satisfied: sacremoses in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from transformers>=4.0.0->pyterrier-t5==0.0.1) (0.0.47)
# Requirement already satisfied: pytz>=2020.1 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from pandas->pyterrier-t5==0.0.1) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from pandas->pyterrier-t5==0.0.1) (2.8.2)
# Requirement already satisfied: typing_extensions in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from torch->pyterrier-t5==0.0.1) (4.1.1)
# Requirement already satisfied: trec-car-tools>=2.5.4 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (2.6)
# Requirement already satisfied: ijson>=3.1.3 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (3.1.4)
# Requirement already satisfied: warc3-wet-clueweb09>=0.2.5 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.2.5)
# Requirement already satisfied: zlib-state>=0.1.3 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.1.5)
# Requirement already satisfied: lz4>=3.1.1 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (3.1.10)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (4.10.0)
# Requirement already satisfied: unlzw3>=0.2.1 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.2.1)
# Requirement already satisfied: warc3-wet>=0.2.3 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.2.3)
# Requirement already satisfied: pyautocorpus>=0.1.1 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.1.8)
# Requirement already satisfied: lxml>=4.5.2 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (4.7.1)
# Requirement already satisfied: cwl-eval>=1.0.10 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from ir-measures>=0.2.0->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.0.10)
# Requirement already satisfied: pytrec-eval-terrier==0.5.1 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from ir-measures>=0.2.0->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.5.1)
# Requirement already satisfied: pyndeval>=0.0.2 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from ir-measures>=0.2.0->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from packaging>=20.0->transformers>=4.0.0->pyterrier-t5==0.0.1) (3.0.7)
# Requirement already satisfied: cython in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from pyjnius~=1.3.0->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.29.27)
# Requirement already satisfied: six>=1.7.0 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from pyjnius~=1.3.0->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from requests->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.26.8)
# Requirement already satisfied: idna<4,>=2.5 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from requests->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from requests->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from requests->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (2.0.11)
# Requirement already satisfied: heapdict in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from chest->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from jinja2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (2.0.1)
# Requirement already satisfied: multiset<3.0,>=2.0 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from matchpy->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (2.1.1)
# Requirement already satisfied: click in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from sacremoses->transformers>=4.0.0->pyterrier-t5==0.0.1) (8.0.4)
# Requirement already satisfied: scikit-learn in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from sklearn->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.0.2)
# Requirement already satisfied: patsy>=0.5.2 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from statsmodels->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.5.2)
# Requirement already satisfied: soupsieve>1.2 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from beautifulsoup4>=4.4.1->ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (2.3.1)
# Requirement already satisfied: cbor>=1.0.0 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from trec-car-tools>=2.5.4->ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.0.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages (from scikit-learn->sklearn->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (3.1.0)
# Building wheels for collected packages: pyterrier-t5
#   Building wheel for pyterrier-t5 (setup.py) ... done
#   Created wheel for pyterrier-t5: filename=pyterrier_t5-0.0.1-py3-none-any.whl size=4865 sha256=ff0259a1d9b3c5d23024668824543a33253c2ebdf96774ad2cdc4e0fa156d99c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3k8qdoxj/wheels/62/2a/70/6116d956d2b72ad4d95989e2b356f910dc007524aae16bffaf
# Successfully built pyterrier-t5
# WARNING: Ignoring invalid distribution -orch (/maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages)
# Installing collected packages: pyterrier-t5
# WARNING: Ignoring invalid distribution -orch (/maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages)
# Successfully installed pyterrier-t5-0.0.1
# WARNING: Ignoring invalid distribution -orch (/maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -orch (/maps/projects/futhark1/data/wzm289/miniconda3/lib/python3.9/site-packages)

# %% [markdown]
# ## Preliminary steps
#
# pyterrier initialization

# %%
import pyterrier as pt
if not pt.started():
    pt.init(tqdm='notebook')
import onir_pt
# Out:
# PyTerrier 0.8.1 has loaded Terrier 5.6 (built by craigmacdonald on 2021-09-17 13:27)
#
# No etc/terrier.properties, using terrier.default.properties for bootstrap configuration.
# Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex.

# %%
import pandas as pd

# corpus
docs_df = pd.read_csv('data/lab_docs.csv', dtype=str)
print(docs_df.shape)
print(docs_df.head())

# topics
topics_df = pd.read_csv('data/lab_topics.csv', dtype=str)
print(topics_df.shape)
print(topics_df.head())

qrels_df = pd.read_csv('data/lab_qrels.csv', dtype=str)
qrels_df = qrels_df.astype({'label': 'int32'})
qrels_df.head()
# Out:
# (2453, 2)
#      docno                                               text
# 0   935016  he emigrated to france with his family in 1956...
# 1  2360440  after being ambushed by the germans in novembe...
# 2   347765  she was the second ship named for captain alex...
# 3  1969335  world war ii was a global war that was under w...
# 4  1576938  the ship was ordered on 2 april 1942 laid down...
# (9, 2)
#        qid                 query
# 0  1015979    president of chile
# 1     2674    computer animation
# 2   340095  2020 summer olympics
# 3  1502917         train station
# 4     2574       chinese cuisine
#        qid    docno label iteration
# 0  1015979  1015979     2         0
# 1  1015979  2226456     1         0
# 2  1015979  1514612     1         0
# 3  1015979  1119171     1         0
# 4  1015979  1053174     1         0

# %%
# Build index

def data_generate():
    for _, row in docs_df.iterrows():
        yield {"docno": row['docno'], "text": row['text']}

iter_indexer = pt.IterDictIndexer("./indexes/default", overwrite = True)
indexref = iter_indexer.index(data_generate(), meta=["docno","text"])

index = pt.IndexFactory.of(indexref)
print(index.getCollectionStatistics().toString())
# Out:
# /tmp/ipykernel_1226292/1935762102.py:8: DeprecationWarning: specifying meta and meta_lengths in IterDictIndexer.index() is deprecated, use constructor instead
#   indexref = iter_indexer.index(data_generate(), meta=["docno","text"])
# Number of documents: 2453
# Number of terms: 23693
# Number of postings: 208487
# Number of fields: 1
# Number of tokens: 273373
# Field names: [text]
# Positions:   false

# %%
br = pt.BatchRetrieve(index) % 100
pipeline = br >> pt.text.get_text(index, 'text')

pipeline.search("wall")
# Out:
#    qid  docid    docno  rank     score query  \
# 0    1   1172   679402     0  6.766137  wall
# 1    1   2110  2391064     1  5.944105  wall
# 2    1   1452   702865     2  5.241024  wall
# 3    1   1357  1221197     3  5.184876  wall
# 4    1   1845  1151865     4  5.151107  wall
# 5    1    293   243238     5  5.124795  wall
# 6    1    592   692168     6  5.055496  wall
# 7    1    319  1607882     7  3.875393  wall
# 8    1   1609  2411328     8  3.815203  wall
# 9    1   1775   354066     9  3.688716  wall
# 10   1   1915  2242428    10  3.688716  wall
# 11   1    203  1455841    11  3.682608  wall
# 12   1   2337   427183    12  3.682608  wall
# 13   1    282  2367752    13  3.670540  wall
# 14   1   1021   680758    14  3.670540  wall
# 15   1    807   193007    15  3.658662  wall
# 16   1    224   104206    16  3.652793  wall
# 17   1    428  1478497    17  3.641191  wall
# 18   1   1485   309607    18  3.629765  wall
# 19   1   1983  1250390    19  3.624117  wall
# 20   1   1955  1073074    20  3.607424  wall
# 21   1    259  1686430    21  3.601941  wall
# 22   1   1356  1561424    22  3.596499  wall
# 23   1   1472   677688    23  3.575117  wall
# 24   1   2115   941063    24  3.559474  wall
#
#                                                  text
# 0   prior to the construction of the berlin wall i...
# 1   in 2013 the rifle range which was constructed ...
# 2   it was one of a number of highly experimental ...
# 3   he was inspired to climb during a cycling holi...
# 4   designed in the shape of a five pointed americ...
# 5   it was created in 1942 by members of the ak wa...
# 6   in washington d c the memorial commemorates ja...
# 7   josef kaplick from 1959 he was an art teacher ...
# 8   an advantage of a wooden mine is that it is ha...
# 9   it served garrison duty on the west wall until...
# 10  the monument is placed in the wall surrounding...
# 11  it was closed in 1892 when the community built...
# 12  the jagdfaust was developed to address this pr...
# 13  konstantin gunz her father was a train driver ...
# 14  those recorded have no known grave anywhere in...
# 15  it was fed from a fixed magazine attached to t...
# 16  codenamed operation neptune and often referred...
# 17  the regiment received the colours from the han...
# 18  between 1897 and 1904 he attended the realgymn...
# 19  the medium is commonly applied to the base wit...
# 20  his father was clare h draper son of general w...
# 21  most jewish ghettos had been created by nazi g...
# 22  the fort was part of the harbor defenses of bo...
# 23  he studied humanities at the el pardo seminary...
# 24  during his apprenticeship baumeister also bega...

# %%
## Rerank from scratch 

knrm = onir_pt.reranker('knrm', 'wordvec_hash', text_field='text')


br = pt.BatchRetrieve(index) % 100
pipeline = br >> pt.text.get_text(index, 'text') >> knrm
pt.Experiment(
    [br, pipeline],
    topics_df,
    qrels_df,
    names=['DPH', 'DPH >> KNRM'],
    eval_metrics=["map", "ndcg", 'ndcg_cut.10', 'P.10', 'mrt']
)
# Out:
# [2022-05-10 16:00:33,122][WordvecHashVocab][DEBUG] [starting] reading cached at /home/wzm289/data/onir/vocab/wordvec_hash/fasttext-wiki-news-300d-1M.p
# [2022-05-10 16:00:34,185][WordvecHashVocab][DEBUG] [finished] reading cached at /home/wzm289/data/onir/vocab/wordvec_hash/fasttext-wiki-news-300d-1M.p [1.06s]
# [2022-05-10 16:00:38,317][onir_pt][DEBUG] using GPU (deterministic)
# [2022-05-10 16:00:45,878][onir_pt][DEBUG] [starting] batches
# batches:   0%|          | 0/185 s<?, ?it/s]
# [2022-05-10 16:00:48,579][onir_pt][DEBUG] [finished] batches: [2.70s] [185it] [68.59it/s]
#           name       map      ndcg  ndcg_cut.10      P.10          mrt
# 0          DPH  0.539915  0.711595     0.840109  0.766667    34.317518
# 1  DPH >> KNRM  0.149483  0.357949     0.229360  0.288889  1413.056607

# %% [markdown]
# ## Vanilla BERT
#
# Contextualized language models, such as [BERT](https://arxiv.org/abs/1810.04805), are much more powerful neural models that have been shown to be effective for ranking.
#
# We'll try using a "vanilla" (or "mono") version of the BERT model. The BERT model is pre-trained for the task of language modeling and next sentence prediction.

# %%
del knrm # clear out memory from KNRM
vbert = onir_pt.reranker('vanilla_transformer', 'bert', text_field='text', vocab_config={'train': True})

pipeline = br % 100 >> pt.text.get_text(index, 'text') >> vbert
pt.Experiment(
    [br, pipeline],
    topics_df,
    qrels_df,
    names=['DPH', 'DPH >> VBERT'],
    baseline=0,
    eval_metrics=["map", "ndcg", 'ndcg_cut.10', 'P.10', 'mrt']
)
# Out:
# 100%|██████████| 231508/231508 s<0ms, 365142.45B/s]
# 100%|██████████| 433/433 s<0ms, 514631.24B/s]
# 100%|██████████| 440473133/440473133 [16.49s<0ms, 26706362.99B/s]
# [2022-05-10 16:06:09,750][onir_pt][DEBUG] using GPU (deterministic)
# [2022-05-10 16:06:09,817][onir_pt][DEBUG] [starting] batches
# batches:   0%|          | 0/185 s<?, ?it/s]
# [2022-05-10 16:06:13,294][onir_pt][DEBUG] [finished] batches: [3.47s] [185it] [53.26it/s]
#            name       map      P.10      ndcg  ndcg_cut.10         mrt  map +  \
# 0           DPH  0.539915  0.766667  0.711595     0.840109   30.337489    NaN
# 1  DPH >> VBERT  0.136422  0.211111  0.337665     0.177415  423.723623    0.0
#
#    map -  map p-value  P.10 +  P.10 -  P.10 p-value  ndcg +  ndcg -  \
# 0    NaN          NaN     NaN     NaN           NaN     NaN     NaN
# 1    9.0      0.00419     0.0     9.0      0.000543     0.0     9.0
#
#    ndcg p-value  ndcg_cut.10 +  ndcg_cut.10 -  ndcg_cut.10 p-value
# 0           NaN            NaN            NaN                  NaN
# 1      0.001491            0.0            9.0             0.000172

# %%
vbert = onir_pt.reranker.from_checkpoint('https://macavaney.us/scibert-medmarco.tar.gz', text_field='text', expected_md5="854966d0b61543ffffa44cea627ab63b")
pipeline = br % 100 >> pt.text.get_text(index, 'text') >> vbert
pt.Experiment(
    [br, pipeline],
    topics_df,
    qrels_df,
    names=['DPH', 'DPH >> VBERT'],
    baseline=0,
    eval_metrics=["map", "ndcg", 'ndcg_cut.10', 'P.10', 'mrt']
)
# Out:
# [2022-05-10 16:11:11,257][onir.util.download][DEBUG] downloaded https://macavaney.us/scibert-medmarco.tar.gz [20.41s] [499M] [41.1MB/s] [md5 hash verified]
# [2022-05-10 16:12:02,711][onir.util.download][DEBUG] downloaded https://s3-us-west-2.amazonaws.com/ai2-s2-research/scibert/pytorch_models/scibert_scivocab_uncased.tar [40.34s] [411M] [17.3MB/s] [md5 hash verified]
# extracting: 411MB [4.23s, 97.0MB/s]
# extracting: 821MB [9.66s, 85.0MB/s]
# [2022-05-10 16:12:30,994][onir_pt][DEBUG] using GPU (deterministic)
# [2022-05-10 16:12:31,057][onir_pt][DEBUG] [starting] batches
# batches:   0%|          | 0/185 s<?, ?it/s]
# [2022-05-10 16:12:33,420][onir_pt][DEBUG] [finished] batches: [2.36s] [185it] [78.36it/s]
#            name       map      P.10      ndcg  ndcg_cut.10         mrt  map +  \
# 0           DPH  0.539915  0.766667  0.711595     0.840109   16.458479    NaN
# 1  DPH >> VBERT  0.507537  0.766667  0.656305     0.783515  286.879604    4.0
#
#    map -  map p-value  P.10 +  P.10 -  P.10 p-value  ndcg +  ndcg -  \
# 0    NaN          NaN     NaN     NaN           NaN     NaN     NaN
# 1    5.0     0.298367     3.0     2.0           1.0     4.0     5.0
#
#    ndcg p-value  ndcg_cut.10 +  ndcg_cut.10 -  ndcg_cut.10 p-value
# 0           NaN            NaN            NaN                  NaN
# 1      0.184318            3.0            4.0              0.31386
